# %%
import matplotlib.pyplot as plt
import csv

재수생 = []
현역 = []
year = []

with open('data.csv', 'r', encoding='cp949') as reader_csv:
    reader = csv.reader(reader_csv, delimiter=',')
    next(reader)
    for row in reader:
        year.append(row[0])
        재수생.append(int(row[10]))
        현역.append(int(row[9]))


#plt.plot(year,data,color='green',marker='o',linestyle='solid')
#plt.plot([1,3,2,5])
plt.rc('font',family='Malgun Gothic')
plt.figure(dpi=300,figsize=(20,5))
plt.plot(year,재수생)
plt.plot(year,현역)

plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import re

# %%
names = []
datas = []
titles = []
    
p = re.compile('\(.*?\)')

with open('subway.csv', 'r', encoding='cp949') as reader_csv:
    reader = csv.reader(reader_csv, delimiter=',')
    titles = next(reader)[3:][0::2]
    
    subway_name = input("지하철 역 이름 입력: ")
    
    for row in reader:
        if (re.sub(p, "", row[2]) == subway_name):
            datas = row[3:][0::2]
            break
    



# plt.plot(year,data,color='green',marker='o',linestyle='solid')
# plt.plot([1,3,2,5])
plt.rc('font',family='Malgun Gothic')
plt.figure(dpi=300,figsize=(20,5))
plt.plot(titles,datas)

plt.show()
# Out:
# 지하철 역 이름 입력: 고려대
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3effec9a2580> in <module>
#      13     for row in reader:
#      14         if (re.sub(p, "", row[2]) == subway_name):
# ---> 15             datas = int(row[3:][0::2])
#      16             break
#      17
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
